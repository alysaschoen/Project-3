# %%
import pandas as pd

# %%
#Import CSV and convert to Pandas DataFrame

airbnb_df = pd.read_csv('Airbnb_Open_Data.csv')
airbnb_df.head()
# Out:
# C:\Users\ryanw\AppData\Local\Temp\ipykernel_34504\1977381797.py:3: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   airbnb_df = pd.read_csv('Airbnb_Open_Data.csv')
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# ...

# %%
#Clear out unnecessary coulmns

airbnb_df = airbnb_df.drop(['host id', 'host_identity_verified', 'host name', 'country', 'country code', 'availability 365',
                           'minimum nights', 'last review'], axis=1)
airbnb_df.head()
# Out:
#         id                                              NAME  \
# 0  1001254                Clean & quiet apt home by the park
# 1  1002102                             Skylit Midtown Castle
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3  1002755                                               NaN
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park
#
#   neighbourhood group neighbourhood       lat      long instant_bookable  \
# 0            Brooklyn    Kensington  40.64749 -73.97237            False
# 1           Manhattan       Midtown  40.75362 -73.98377            False
# 2           Manhattan        Harlem  40.80902 -73.94190             True
# 3            Brooklyn  Clinton Hill  40.68514 -73.95976             True
# 4           Manhattan   East Harlem  40.79851 -73.94399            False
#
#   cancellation_policy        room type  Construction year  price service fee  \
# 0              strict     Private room             2020.0  $966        $193
# ...

# %%
# Check neighbourhood group' for any errors

hood_values = airbnb_df['neighbourhood group'].unique()
value_counts = airbnb_df['neighbourhood group'].value_counts()
print(hood_values)
print('-----------------')
print(value_counts)
# Out:
# ['Brooklyn' 'Manhattan' 'brookln' 'manhatan' 'Queens' nan 'Staten Island'
#  'Bronx']
# -----------------
# Manhattan        43792
# Brooklyn         41842
# Queens           13267
# Bronx             2712
# Staten Island      955
# brookln              1
# manhatan             1
# Name: neighbourhood group, dtype: int64

# %%
#Change 'brookln' to Brooklyn

brookln = airbnb_df.loc[airbnb_df['neighbourhood group']=='brookln']
airnbn_df = airbnb_df.loc[brookln.index, 'neighbourhood group'] = 'Brooklyn' 

#Change 'manhatan' to Manhattan

manhatan = airbnb_df.loc[airbnb_df['neighbourhood group']=='manhatan']
airnbn_df = airbnb_df.loc[manhatan.index, 'neighbourhood group'] = 'Manhattan'

# %%
#Make sure the values have been changed

new_hood_values = airbnb_df['neighbourhood group'].unique()
new_value_counts = airbnb_df['neighbourhood group'].value_counts()
print(new_hood_values)
print('-----------------------------------------------------------------------')
print(new_value_counts)
# Out:
# ['Brooklyn' 'Manhattan' 'Queens' nan 'Staten Island' 'Bronx']
# -----------------------------------------------------------------------
# Manhattan        43793
# Brooklyn         41843
# Queens           13267
# Bronx             2712
# Staten Island      955
# Name: neighbourhood group, dtype: int64

# %%
#Change column names

airbnb_df = airbnb_df.rename(columns={
    'NAME': 'Name',
    'neighbourhood group': 'Borough',
    'neighbourhood': 'Neighbourhood',
    'lat': 'Lat',
    'long': 'Lon',
    'instant_bookable': 'Instant Booking',
    'cancellation_policy': 'Cancellation Policy',
    'room type': 'Room Type',
    'Construction year': 'Construction Year',
    'price': 'Price Per Night',
    'service fee': 'Service Fee',
    'number of reviews': 'Total Reviews',
    'reviews per month': 'Reviews Per Month',
    'review rate number': 'Review Rate Number',
    'calculated host listings count': 'Host Listings Count',
    'house_rules': 'House Rules',
    'license': 'License'
})

airbnb_df.head()
# Out:
#         id                                              Name    Borough  \
# 0  1001254                Clean & quiet apt home by the park   Brooklyn
# 1  1002102                             Skylit Midtown Castle  Manhattan
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  Manhattan
# 3  1002755                                               NaN   Brooklyn
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  Manhattan
#
#   Neighbourhood       Lat       Lon Instant Booking Cancellation Policy  \
# 0    Kensington  40.64749 -73.97237           False              strict
# 1       Midtown  40.75362 -73.98377           False            moderate
# 2        Harlem  40.80902 -73.94190            True            flexible
# 3  Clinton Hill  40.68514 -73.95976            True            moderate
# 4   East Harlem  40.79851 -73.94399           False            moderate
#
#          Room Type  Construction Year Price Per Night Service Fee  \
# ...

# %%
#Check data types are usable for analysis

data_types = airbnb_df.dtypes
print(data_types)
# Out:
# id                       int64
# Name                    object
# Borough                 object
# Neighbourhood           object
# Lat                    float64
# Lon                    float64
# Instant Booking         object
# Cancellation Policy     object
# Room Type               object
# Construction Year      float64
# Price Per Night         object
# Service Fee             object
# Total Reviews          float64
# Reviews Per Month      float64
# Review Rate Number     float64
# Host Listings Count    float64
# House Rules             object
# License                 object
# dtype: object
